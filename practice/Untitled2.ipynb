# %%
while True:
    x = input("Do you want change parameter? [1 : Yes, 0 : No] \n")
    if x == str(1) :
        print("Ok....")
        break
    elif x == str(0) :
        print("Go training!")
        break
    # elif x ... 
    print("Wrong value entered!")
    
    
while True:
    y = int(input("Select parameter\n 1 : lr (%.5f)\n 2 : epochs (%d)\n 3 : batch_size (%d)\n 4 : weight_decay (%.4f)\n 5 : prune_per_c (%.2f)\n 6 : prune_per_f (%.2f)\n 7 : prune_per_o (%.2f)\n 8 : test_iter (%d)\n 9 : prune_iter (%d)\n 0 : exit \n"
                % (param.lr, param.epochs, param.batch_size, param.weight_decay, param.prune_per_c, param.prune_per_f, param.prune_per_o, param.test_iter, param.prune_iter)
                 ))
    
    if y == 1 :
        a = param.lr
        print("Current value [lr : %.5f]" % param.lr)
        param.lr = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.lr))
    elif y == 2 :
        a = param.epochs
        print("Current value [lr : %.5f]" % param.epochs)
        param.epochs = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.epochs))
    elif y == 3 :
        a = param.batch_size
        print("Current value [lr : %.5f]" % param.batch_size)
        param.batch_size = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.batch_size))
    elif y == 4 :
        a = param.weight_decay
        print("Current value [lr : %.5f]" % param.weight_decay)
        param.weight_decay = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.weight_decay))
    elif y == 5 :
        a = param.prune_per_c
        print("Current value [lr : %.5f]" % param.prune_per_c)
        param.prune_per_c = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.prune_per_c))
    elif y == 6 :
        a = param.prune_per_f
        print("Current value [lr : %.5f]" % param.prune_per_f)
        param.prune_per_f = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.prune_per_f))
    elif y == 7 :
        a = param.prune_per_o
        print("Current value [lr : %.5f]" % param.prune_per_o)
        param.prune_per_o = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.prune_per_o))
    elif y == 8 :
        a = param.test_iter
        print("Current value [lr : %.5f]" % param.test_iter)
        param.test_iter = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.test_iter))
    elif y == 9 :
        a = param.prune_iter
        print("Current value [lr : %.5f]" % param.prune_iter)
        param.prune_iter = float(input("input parameters (float) \n"))
        print("[lr : %.5f] -> [lr : %.5f]" % (a, param.prune_iter))
    elif y == 0:
        z = int(input("Are u sure? [1 : Yes, 0 : No]"))
        if z == 1:
            break
    # elif x ... 
#    print("Wrong value entered!")

while True:
    x = input("Do you want change model's layer? [1 : Yes, 0 : No] \n")
    if x == str(1) :
        print("Ok....")
        break
    elif x == str(0) :
        print("Go training!")
        break
    # elif x ... 
    print("Wrong value entered!")
    
layername = []
for name, p in model.named_parameters():
    if 'weight' in name:
        layername.append(name[:len(name)-7])
layernum = len(layername)

while True:
    print("Select layer")
    for i in range(layernum):
        print("%d : %s" % (i+1, layername[i]))
    print("0 : exit")
    x = int(input())
    if x == 1:
        print(11)
    # 그냥 리스트화해서 다 바꾸면 이프문 안써도 될듯?
